# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
# ## FACULTAD DE SISTEMA
# ### Nombre: Josue Diaz
#
#
# **Tema: “Análisis y Comparar Celulares”**
#
# **Objetivos:**
#
# -   Analizar los precios de los precios de Samsung.
#
# -   Relacion de la Fecha de Lanzamiento y el Precio de Samsung.
#
# -   Analizar los precios de los precios del Iphone.
#
# -   Relacion de la Fecha de Lanzamiento y el Precio del Iphone.
#
# -   Relacionar la RAM en cada modelo de los telefonos Samsung.
#
# -   Relacionar el tamaño de pantalla en cada modelo de los telefonos Samsung.
#
# -   Relacionar las resoluciones de pantalla en cada modelo de los telefonos Samsung.
#
# -   Relacionar los sistemas operativos de cada modelo de los telefonos Samsung.
#
# -   Relacionar los tipos de pantalla de cada modelo de los telefonos Samsung.
#
# -   Relacionar las bateria de cada modelo de los telefonos Samsung.
#
# -   Relacionar los pesos de cada modelo de los telefonos Samsung.
#
# -   Relacionar los sims de cada modelo de los telefonos Samsung.
#
# -   Relacionar la RAM en cadad modelo de los telefonos Iphone.
#
# -   Relacionar el tamaño de pantalla en cadad modelo de los telefonos Iphone.
#
# -   Relacionar las resoluciones de pantalla en cadad modelo de los telefonos Iphone.
#
# -   Relacionar los procesadores de cada modelo de los telefonos Iphones.
#
# -   Relacionar los camaras frontales de cada modelo de los telefonos Iphone.
#
# -   Relacionar las bateria de cada modelo de los telefonos Iphone.
#
# -   Relacionar los pesos de cada modelo de los telefonos Iphone.
#
# -   Relacionar los sims de cada modelo de los telefonos Iphone.
#
#
#
# **Desarrollo**
#
# Como la herramienta scrapy se logor sacar la informacion de estos siguientes links http://socialcompare.com/en/comparison/apple-iphone-product-line-comparison y http://socialcompare.com/en/comparison/samsung-galaxy-s-product-line que contiene la informacion de los modelos de telefonos que iphone y samsung a sacado al mercado junto con todas sus especificaciones.

# %% [markdown]
# **Importamos Librerias**

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import numpy as np
import seaborn as sns

# %% [markdown]
# **Lectura de los datos**

# %%
path1 = "C:/Users/josh_/Documents/GitHub/py-diaz-veloz-josue-daniel/Proyecto-2B/Scrapy/proyecto2b/datosApple.csv"
df_Iphone = pd.read_csv(path1)

# %%
path2 = "C:/Users/josh_/Documents/GitHub/py-diaz-veloz-josue-daniel/Proyecto-2B/Scrapy/proyecto2b/datosSamsung.csv"
df_Samsung = pd.read_csv(path2)

# %% [markdown]
# **Analizar los precios de los precios de Samsung**

# %%
df_Samsung["FECHA LANZAMIENTO"]=pd.to_datetime(df_Samsung["FECHA LANZAMIENTO"])
phone_date = df_Samsung.sort_values(by = ['FECHA LANZAMIENTO'],ascending=False)
columns=filtered_columns = ['MODELO','FECHA LANZAMIENTO','PRECIOS']

phone_filtered = phone_date.reindex(columns=filtered_columns)
phone_filtered.head(30)
# Out:
#                        MODELO FECHA LANZAMIENTO  PRECIOS
# 0         Samsung Galaxy S10+        2019-03-08     1000
# 1          Samsung Galaxy S10        2019-03-08      900
# 2                 Galaxy S10e        2019-03-08      750
# 3          Samsung Galaxy S9+        2018-03-16      840
# 4           Samsung Galaxy S9        2018-03-16      720
# 5          Samsung Galaxy S8+        2017-04-21      850
# 6           Samsung Galaxy S8        2017-04-21      750
# 7      Samsung Galaxy S7 Edge        2016-03-11      779
# 8           Samsung Galaxy S7        2016-03-11      669
# 9           Samsung Galaxy S6        2015-04-15      600
# 10      Samsung Galaxy Note 4        2014-10-15      750
# 12    Samasung Galasy S5 mini        2014-07-01      550
# 11          Samsung Galaxy S5        2014-04-11      650
# 13         Samsung Galaxy S 4        2013-04-26      640
# 15     Samsung Galaxy S3 Mini        2012-11-01      450
# ...

# %% [markdown]
# **Relacion de la Fecha de Lanzamiento y el Precio de Samsung**

# %%
plt.figure(1,figsize=(20,5))
plt.plot(phone_date['FECHA LANZAMIENTO'], phone_date['PRECIOS'])
plt.suptitle('Precio Inicial vs Fecha de Lanzamiento') 
plt.show()

# %% [markdown]
# **Analizar los precios de los precios del Iphone**

# %%
df_Iphone["FECHA LANZAMIENTO"]=pd.to_datetime(df_Iphone["FECHA LANZAMIENTO"])
phone_date1 = df_Iphone.sort_values(by = ['FECHA LANZAMIENTO'],ascending=False)
columns=filtered_columns = ['MODELO','FECHA LANZAMIENTO','PRECIOS']

phone_filtered1 = phone_date1.reindex(columns=filtered_columns)
phone_filtered1.head(30)
# Out:
#                  MODELO FECHA LANZAMIENTO  PRECIOS
# 0   iPhone SE (2nd Gen)        2020-04-24      540
# 1             iPhone 11        2019-09-20      849
# 2         iPhone 11 Pro        2019-09-20     1149
# 3     iPhone 11 Pro Max        2019-09-20     1249
# 4             iPhone XR        2018-10-26      749
# 5             iPhone XS        2018-09-28      999
# 6         iPhone XS Max        2018-09-28     1099
# 7              iPhone X        2017-10-27      999
# 8         iPhone 8 Plus        2017-09-15      799
# 9              iPhone 8        2017-09-15      699
# 11             iPhone 7        2016-09-16      715
# 10        iPhone 7 Plus        2016-09-16      809
# 12            iPhone SE        2016-03-24      449
# 13       iPhone 6s Plus        2015-09-12      783
# 14            iPhone 6s        2015-09-12      689
# 15        iPhone 6 Plus        2014-09-09      700
# 16             iPhone 6        2014-09-09      688
# ...

# %% [markdown]
# **Relacion de la Fecha de Lanzamiento y el Precio del Iphone**

# %%
plt.figure(1,figsize=(20,5))
plt.plot(phone_date1['FECHA LANZAMIENTO'], phone_date1['PRECIOS'])
plt.suptitle('Precio Inicial vs Fecha de Lanzamiento') 
plt.show()

# %% [markdown]
# **Relacionar la RAM en cadad modelo de los telefonos Samsung.**

# %%
modelo_s = df_Samsung['MODELO']
ram_s = df_Samsung['RAM (GB)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(modelo_s,ram_s,color = 'blue')
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# **Relacionar la RAM en cadad modelo de los telefonos Iphone.**

# %%
modelo_s = df_Iphone['MODELO']
ram_s = df_Iphone['RAM (GB)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(modelo_s,ram_s,color = 'red')
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# **Relacionar el tamaño de pantalla en cadad modelo de los telefonos Samsung.**

# %%
modelo_s = df_Samsung['MODELO']
ram_s = df_Samsung['TAMAÑO PANTALLA (in)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(modelo_s,ram_s,color = 'blue')
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# **Relacionar el tamaño de pantalla en cadad modelo de los telefonos Iphones.**

# %%
modelo_s = df_Iphone['MODELO']
ram_s = df_Iphone['TAMAÑO PANTALLA (in)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(modelo_s,ram_s,color = 'red')
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# **Relacionar las resolucion de pantalla en cadad modelo de los telefonos Samsung.**

# %%
plt.figure(figsize=(9,10))
plt.title("Reluciones de pantalla de telefonos Samsung")
df_Samsung.groupby([' RESOLUCION PANTALLA'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los sistemas operativos de cada modelo de los telefonos Iphone.**

# %%
plt.figure(figsize=(9,10))
plt.title("Reluciones de pantalla de telefonos Iphone")
df_Iphone.groupby([' RESOLUCION PANTALLA'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los sistemas operativos de cada modelo de los telefonos Samsung.**

# %%
plt.figure(figsize=(9,10))
plt.title("Sistemas Operativos de telefonos Samsung")
df_Samsung.groupby(['SO'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los procesador de cada modelo de los telefonos Iphone.**

# %%
plt.figure(figsize=(9,10))
plt.title("Sistemas Operativos de telefonos Iphone")
df_Iphone.groupby(['PROCESADOR'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los tipos de pantalla de cada modelo de los telefonos Samsung.**

# %%
plt.figure(figsize=(9,10))
plt.title("Tipos de Pantallas de telefonos Samsung")
df_Samsung.groupby(['TIPO PANTALLA'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los tipos de camaras frontales de cada modelo de los telefonos Iphone.**

# %%
plt.figure(figsize=(9,10))
plt.title("Tipos de Pantallas de telefonos Samsung")
df_Iphone.groupby(['CAMARA FRONTAL'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar las bateria de cada modelo de los telefonos Samsung.**

# %%
bateria_i = df_Samsung['BATERIA (mAh)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(df_Samsung['MODELO'],bateria_i,color='blue')
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# **Relacionar las bateria de cada modelo de los telefonos Iphone.**

# %%
bateria_i = df_Iphone['BATERIA (mAh)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(df_Iphone['MODELO'],bateria_i,color='red')
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# **Relacionar los pesos de cada modelo de los telefonos Samsung.**

# %%
peso_i = df_Samsung['PESO (g)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(df_Samsung['MODELO'],peso_i,color='blue')
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# **Relacionar los pesos de cada modelo de los telefonos Iphone.**

# %%
peso_i = df_Iphone['PESO (g)']
plt.figure(1,figsize=(20,5))
plt.xticks(rotation = 'vertical')
plt.bar(df_Iphone['MODELO'],peso_i,color='red')
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# **Relacionar los sims de cada modelo de los telefonos Samsung.**

# %%
plt.figure(figsize=(9,10))
plt.title("Tipos de SIMS de telefonos Samsung")
df_Samsung.groupby(['SIM'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)

# %% [markdown]
# **Relacionar los sims de cada modelo de los telefonos Iphone.**

# %%
plt.figure(figsize=(9,10))
plt.title("Tipos de SIMS de telefonos Iphone")
df_Iphone.groupby(['SIM'])['MODELO'].count().plot(kind="pie",autopct='%1.1f%%', startangle=90)
